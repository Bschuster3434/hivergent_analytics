# %%
import pandas
import requests
import datetime
import time
import json
from dateutil import parser

# %%
#Different type of Ripple Transactions...
#https://ripple.com/build/transactions/
#denomination of XRP is 1,000,000 units to 1 XRP

# %%
#https://ripple.com/build/data-api-v2/#get-transactions
url_endpoint = "https://data.ripple.com/v2/transactions/"
starting_datetime = datetime.datetime(2017,12,31,0,0)
iso_starting_datetime = starting_datetime.isoformat()
ending_timestamp = datetime.datetime(2017,12,31,1,0)
iso_ending_timestamp = ending_timestamp.isoformat()
total_api_calls = 100

# %%
#Datapoints per transaction needed
# Timestamp
# Unique Hash
# Account Sending
# Account Receiving (May be smart contract)
# Tx Fee
# Size of Data (I don't see this here... I'll skip it for now)
# Network Name (duh)
# Transaction Status
# Value of Tx

# %%
params = {"start": iso_starting_datetime , "end" : iso_ending_timestamp, "limit" : 100}
resp = requests.get(url_endpoint, params=params)
resp_dict = json.loads(resp.content)

# %%
resp_dict
# Out:
# {u'count': 100,
#  u'marker': u'20171231000002|000035444821|00019',
#  u'result': u'success',
#  u'transactions': [{u'date': u'2017-12-31T00:00:00+00:00',
#    u'hash': u'9E7F95ED41B5ECFD1BE8E10390C838AAA9A75FCA22C4838947739A70B69DE782',
#    u'ledger_hash': u'AAED8C6844274FD65A252C88452837D28D03DDFFC7CF4C0ED9531FB8E9A7A79E',
#    u'ledger_index': 35444819,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Account': u'rfyNC9KSZz28NUwrTXhV7tE7cUAavby5ri',
#         u'Balance': u'143369919',
#         u'Flags': 0,
#         u'OwnerCount': 14,
#         u'Sequence': 187438},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'51085CD0DEFFC9B0E732D9EBD70D961E402312D98EF8FEF29166B773498A8D16',
#        u'PreviousFields': {u'Balance': u'143369939', u'Sequence': 187437},
#        u'PreviousTxnID': u'CFB628326DB7EF17214A5D71CF2DD9DA2C59A9CC5F71291A0F2C3CD5DF0A4CD2',
#        u'PreviousTxnLgrSeq': 35444818}},
#      {u'CreatedNode': {u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'64509CB59515538982B6C5CCF3C7D00BF17843EFDB13E60C7D292EDAC7D30A5D',
#        u'NewFields': {u'Account': u'rfyNC9KSZz28NUwrTXhV7tE7cUAavby5ri',
#         u'BookDirectory': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06E472C8ECD145',
#         u'OwnerNode': u'0000000000000011',
#         u'Sequence': 187437,
#         u'TakerGets': u'2257794',
#         u'TakerPays': {u'currency': u'USD',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'4.3801915'}}}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000000000',
#         u'Owner': u'rfyNC9KSZz28NUwrTXhV7tE7cUAavby5ri',
#         u'RootIndex': u'0E27431A94898C0E8A0B323B16717C73A012F5554CC552BFE31234CA22286E27'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'98AA18EB165EEAF725975D19F61E322029B816A4EFEE50880663EC7F3507C6AB'}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'rfyNC9KSZz28NUwrTXhV7tE7cUAavby5ri',
#         u'BookDirectory': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F073B82242DF146',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000000011',
#         u'PreviousTxnID': u'F902C6242B822DB4E43D4B2C594F8E178E95A8110452324AAEAFEFA6A4B7D584',
#         u'PreviousTxnLgrSeq': 35444313,
#         u'Sequence': 187423,
#         u'TakerGets': u'2221674',
#         u'TakerPays': {u'currency': u'USD',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'4.5227839'}},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'BADC236C1088BB2DC6D269811442910275B26F94EC047161CB7EEF599B0059A9'}},
#      {u'CreatedNode': {u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06E472C8ECD145',
#        u'NewFields': {u'ExchangeRate': u'4F06E472C8ECD145',
#         u'RootIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06E472C8ECD145',
#         u'TakerPaysCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerPaysIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1'}}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'4F073B82242DF146',
#         u'Flags': 0,
#         u'RootIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4

#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'310D1C793E389AA59C22EEE8A1BAD67BDE536404CD00ECDEAC37D24DB6EC1FD1',
#        u'PreviousFields': {u'Balance': u'202577240',
#         u'OwnerCount': 16,
#         u'Sequence': 324733},
#        u'PreviousTxnID': u'EDCE56F305B22B44CA5482C25107A4033769A2FA86340B2D9B591CCE596538E9',
#        u'PreviousTxnLgrSeq': 35444815}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexNext': u'0000000000000000',
#         u'IndexPrevious': u'0000000000000000',
#         u'Owner': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#         u'RootIndex': u'9B1A924CAC99619BAB5E2E36970C151C5EB23BD12525F6F07BDF52480D0D745E'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'333B5C2355D729D7D87B80C8DD023A86E764A823E6DBC874E4287190E7385740'}},
#      {u'CreatedNode': {u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D6055039020B038CC32',
#        u'NewFields': {u'ExchangeRate': u'55039020B038CC32',
#         u'RootIndex': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D6055039020B038CC32',
#         u'TakerGetsCurrency': u'0000000000000000000000004254430000000000',
#         u'TakerGetsIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1',
#         u'TakerPaysCurrency': u'0000000000000000000000004254430000000000',
#         u'TakerPaysIssuer': u'06A148131B436B2561C85967685B098E050EED4E'}}},
#      {u'CreatedNode': {u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'FBBCCF669260B49C1A899A7C2399AA5E2E973797C65FA341100F76FA6841A655',
#        u'NewFields': {u'Account': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#         u'BookDirectory': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D6055039020B038CC32',
#         u'OwnerNode': u'0000000000000015',
#         u'Sequence': 324733,
#         u'TakerGets': {u'currency': u'BTC',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'76.7674013756892'},
#         u'TakerPays': {u'currency': u'BTC',
#          u'issuer': u'rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL',
#          u'value': u'76.9896430024792'}}}}],
#     u'TransactionIndex': 3,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#     u'Fee': u'10',
#     u'Flags': 2147483648L,
#     u'LastLedgerSequence': 35444838,
#     u'Sequence': 324733,
#     u'SigningPubKey': u'03355CC886EB9C7FE8B69328D76AB2854525F35AB748839CC80D3B2F5CA9766DD1',
#     u'TakerGets': {u'currency': u'BTC',
#      u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#      u'value': u'76.7674013756892'},
#     u'TakerPays': {u'currency': u'BTC',
#      u'issuer': u'rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL',
#      u'value': u'76.9896430024792'},
#     u'TransactionType': u'OfferCreate',
#     u'TxnSignature': u'3045022100E5E36029064D35E4FEFD661592E4BB5F84C3ABDEBFB10CE4E4BA9C376AD30C5202203E035A1023184325772EDA8EA5E8825F76404CA6187E75767E01DD83484C8D7F'}},
#   {u'date': u'2017-12-31T00:00:00+00:00',
#    u'hash': u'4F30321179D86FB20DF41BC2E454EAC8749B43FA21696E14FA08DE1D2F7F43B8',
#    u'ledger_hash': u'AAED8C6844274FD65A252C88452837D28D03DDFFC7CF4C0ED9531FB8E9A7A79E',
#    u'ledger_index': 35444819,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Account': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#         u'Balance': u'202577200',
#         u'Flags': 0,
#         u'OwnerCount': 16,
#         u'Sequence': 324735},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'310D1C793E389AA59C22EEE8A1BAD67BDE536404CD00ECDEAC37D24DB6EC1FD1',
#        u'PreviousFields': {u'Balance': u'202577230',
#         u'OwnerCount': 17,
#         u'Sequence': 324734},
#        u'PreviousTxnID': u'B4BC0625D1B330171ED360B2BC1FC3A1A91FF3CC970D69EA19FF4F2A49C82FB6',
#        u'PreviousTxnLgrSeq': 35444819}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexNext': u'0000000000000000',
#         u'IndexPrevious': u'0000000000000000',
#         u'Owner': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#         u'RootIndex': u'9B1A924CAC99619BAB5E2E36970C151C5EB23BD12525F6F07BDF52480D0D745E'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'333B5C2355D729D7D87B80C8DD023A86E764A823E6DBC874E4287190E7385740'}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'5503902163092A32',
#         u'Flags': 0,
#         u'RootIndex': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D605503902163092A32',
#         u'TakerGetsCurrency': u'0000000000000000000000004254430000000000',
#         u'TakerGetsIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1',
#         u'TakerPaysCurrency': u'0000000000000000000000004254430000000000',
#         u'TakerPaysIssuer': u'06A148131B436B2561C85967685B098E050EED4E'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D605503902163092A32'}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'rhXZDebYFALnTyWhFFPQJNqREGa27JPYiA',
#         u'BookDirectory': u'AAFE1CA969835B3EC8878A17CD6E9607D64EC3976BB22D605503902163092A32',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000000015',
#         u'PreviousTxnID': u'0D6768970A54C58636FD14BC956141CB4726A06F9A5CF0516F1C12B436E9D6E5',
#         u'PreviousTxnLgrSeq': 35444815,
#         u'Sequence': 324731,
#         u'TakerGets': {u'currency': u'BTC',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u

#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000000021',
#         u'PreviousTxnID': u'0314CC5456F223F026E0632EAA28F0C37CA3B792742A353FC7593C39F4D19375',
#         u'PreviousTxnLgrSeq': 35444817,
#         u'Sequence': 9281737,
#         u'TakerGets': u'100000000',
#         u'TakerPays': {u'currency': u'USD',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'195.4744356496438'}},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'005696D70CCB82DCD438DB6CDE5ED88E438C16F915E14E8144D04102C83CF3F3'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000000020',
#         u'Owner': u'rhS2H7ETM3wBkFETvYycoUm9FEDYi44Pg4',
#         u'RootIndex': u'A86F1886910A8B86BB0221982AA3E26C015FD3455EFCDABA35FE905AA772749C'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'384C4F6876B8F077B52619532E417E2B0D2081786841349BF46C1D0C5FD214BE'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'rhS2H7ETM3wBkFETvYycoUm9FEDYi44Pg4',
#         u'Balance': u'7326917375',
#         u'Flags': 0,
#         u'OwnerCount': 27,
#         u'Sequence': 9281744},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'6B555B9A14F4E40BB83EF68DE332ECCCC84D310AFFABBAA3606F7969C688EC21',
#        u'PreviousFields': {u'Balance': u'7326932375',
#         u'OwnerCount': 28,
#         u'Sequence': 9281743},
#        u'PreviousTxnID': u'3F74971067DFBC92BBB411352EF7A32AA73EBFA4F07001DF21E2296E762321BB',
#        u'PreviousTxnLgrSeq': 35444819}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'4F06F1D462FEE436',
#         u'Flags': 0,
#         u'RootIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06F1D462FEE436',
#         u'TakerGetsCurrency': u'0000000000000000000000000000000000000000',
#         u'TakerGetsIssuer': u'0000000000000000000000000000000000000000',
#         u'TakerPaysCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerPaysIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06F1D462FEE436'}}],
#     u'TransactionIndex': 7,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rhS2H7ETM3wBkFETvYycoUm9FEDYi44Pg4',
#     u'Fee': u'15000',
#     u'Flags': 2147483648L,
#     u'OfferSequence': 9281737,
#     u'Sequence': 9281743,
#     u'SigningPubKey': u'030C673ADE7B422F29474D11DA07D7A32A73C29CDA5A1ED6535B0E525979B9199C',
#     u'TransactionType': u'OfferCancel',
#     u'TxnSignature': u'304402204831060B1008F1D6343E1839067C941D6147FB739489D0E6EDE3837575E7CF1E02202A6995F9149045B7DCC7CD281EA9D0B92366B9C90F13971562083641F78DC676'}},
#   {u'date': u'2017-12-31T00:00:00+00:00',
#    u'hash': u'458BFC60CE2D23189298076B886D176434D10C114CD3D11B28E2F86019487BCC',
#    u'ledger_hash': u'AAED8C6844274FD65A252C88452837D28D03DDFFC7CF4C0ED9531FB8E9A7A79E',
#    u'ledger_index': 35444819,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'Balance': u'274835133',
#         u'Flags': 8388608,
#         u'OwnerCount': 5,
#         u'Sequence': 380207},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'EF6794F5513959B2837E95BF3A1F8566A2ADD72D6AE3DD74B2B0D0A34C489B4C',
#        u'PreviousFields': {u'Balance': u'274835145', u'Sequence': 380206},
#        u'PreviousTxnID': u'AEA789007A3EBC13FAA00B268ED000B39DDEDEA2B523D69558CBFC0CF24C0C1B',
#        u'PreviousTxnLgrSeq': 35444818}}],
#     u'TransactionIndex': 8,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#     u'Fee': u'12',
#     u'Flags': 2147483648L,
#     u'LastLedgerSequence': 35444820,
#     u'OfferSequence': 380198,
#     u'Sequence': 380206,
#     u'SigningPubKey': u'0291D2EBF202C1F09DA301078ADD497797CD66CD5AA5AB667D0EB3B61FA600F54D',
#     u'TransactionType': u'OfferCancel',
#     u'TxnSignature': u'3045022100D5E129A83A2EA4069F67C2F2F7C73C88BF5E433D00608529843EE911DC031F81022023F731AFC541053B0A3D59FCB4779E837AFDA3CFB50EA7BEAF802D3D99C03586'}},
#   {u'date': u'2017-12-31T00:00:00+00:00',
#    u'hash': u'6B15DB19DE27DF7E2C664EFFF0E010B122F1FC02F064E5AD51732CFA95DF82C0',
#    u'ledger_hash': u'AAED8C6844274FD65A252C88452837D28D03DDFFC7CF4C0ED9531FB8E9A7A79E',
#    u'ledger_index': 35444819,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'Balance': u'274835121',
#         u'Flags': 8388608,
#         u'OwnerCount': 5,
#         u'Sequence': 380208},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'EF6794F5513959B2837E95BF3A1F8566A2ADD72D6AE3DD74B2B0D0A34C489B4C',
#        u'PreviousFields': {u'Balance': u'274835133', u'Sequence': 380207},
#        u'PreviousTxnID': u'458BFC60CE2D23189298076B886D176434D10C114CD3D11B28E2F86019487BCC',
#        u'PreviousTxnLgrSeq': 35444819}}],
#     u'TransactionIndex': 9,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',

#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'Owner': u'rpasYR6Lrw6iKxUmNR7sLmcSPmau39D1gJ',
#         u'RootIndex': u'B937CC88FCAF18886CC8D4B19A5326F56B0B84E06AE511407B072DE348E05376'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'4EE049F49C4FE61B90FEE1CB16497907998FB6530A87BCAD3319D356DB6FDB71'}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'500573E48B364C72',
#         u'Flags': 0,
#         u'RootIndex': u'7254404DF6B7FBFFEF34DC38867A7E7DE610B513997B7880500573E48B364C72',
#         u'TakerGetsCurrency': u'0000000000000000000000000000000000000000',
#         u'TakerGetsIssuer': u'0000000000000000000000000000000000000000',
#         u'TakerPaysCurrency': u'000000000000000000000000434E590000000000',
#         u'TakerPaysIssuer': u'41C8BE2C0A6AA17471B9F6D0AF92AAB1C94D5A25'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'7254404DF6B7FBFFEF34DC38867A7E7DE610B513997B7880500573E48B364C72'}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'rpasYR6Lrw6iKxUmNR7sLmcSPmau39D1gJ',
#         u'BookDirectory': u'7254404DF6B7FBFFEF34DC38867A7E7DE610B513997B7880500573E48B364C72',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000000001',
#         u'PreviousTxnID': u'E695C676872AEEF664794A7811A15957F0E564F9A812B717F29B824B71AD9CF4',
#         u'PreviousTxnLgrSeq': 35444818,
#         u'Sequence': 10052914,
#         u'TakerGets': u'177262266',
#         u'TakerPays': {u'currency': u'CNY',
#          u'issuer': u'razqQKzJRdB4UxFPWf5NEpEG3WMkmwgcXA',
#          u'value': u'2720.621806100201'}},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'877C52F5C9DEB4C0E8AE0C9536251CB83ACD2947A471CC6FC1667B0F1B2270E0'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'rpasYR6Lrw6iKxUmNR7sLmcSPmau39D1gJ',
#         u'Balance': u'6151493868',
#         u'Flags': 0,
#         u'OwnerCount': 27,
#         u'Sequence': 10052921},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'E9293AF964F2B20467530673C8F32741ED03DEF52F6B6625B4D837C155856C26',
#        u'PreviousFields': {u'Balance': u'6151508868',
#         u'OwnerCount': 28,
#         u'Sequence': 10052920},
#        u'PreviousTxnID': u'2EC251BB34EE5B7E40CB534E82A77EFEBF1EEA75D932771E312663E72270A36D',
#        u'PreviousTxnLgrSeq': 35444819}}],
#     u'TransactionIndex': 14,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rpasYR6Lrw6iKxUmNR7sLmcSPmau39D1gJ',
#     u'Fee': u'15000',
#     u'Flags': 2147483648L,
#     u'OfferSequence': 10052914,
#     u'Sequence': 10052920,
#     u'SigningPubKey': u'03CF1DFB34A96363FF2B91638FCE51E6D7B88419729E9A81ABC99A9512FFB9C733',
# ...
#        u'NewFields': {u'ExchangeRate': u'580FE6C8783C9565',
#         u'RootIndex': u'A7A2258942BF79A1C2A55DA88560879DC312966AFDD1CD05580FE6C8783C9565',
#         u'TakerGetsCurrency': u'0000000000000000000000004A50590000000000',
#         u'TakerGetsIssuer': u'6F2531F2B8CDB96D6D986D9D75CC0156DF2C5387'}}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'BookDirectory': u'A7A2258942BF79A1C2A55DA88560879DC312966AFDD1CD05580FE4BF9232DEF0',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000003FF0',
#         u'PreviousTxnID': u'696BB2807A2ACECBC488EDA1DE97015D9CD4D6C9BD18077447766AEAE878B9EE',
#         u'PreviousTxnLgrSeq': 35444791,
#         u'Sequence': 1501583,
#         u'TakerGets': {u'currency': u'JPY',
#          u'issuer': u'rB3gZey7VWHYRqJHLoHDEJXJ2pEPNieKiS',
#          u'value': u'887.25299'},
#         u'TakerPays': u'3969247'},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'D102092DF3AE4C8A020B2A57C4710FAD96BAEA9C5D315FEC76CE411ABEC0B97B'}}],
#     u'TransactionIndex': 14,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#     u'Fee': u'15',
#     u'Flags': 2147483648L,
#     u'LastLedgerSequence': 35444822,
#     u'OfferSequence': 1501583,
#     u'Sequence': 1501597,
#     u'SigningPubKey': u'02E2F1208D1715E18B0957FC819546FA7434B4A19EE38321932D2ED28FA090678E',
#     u'TakerGets': {u'currency': u'JPY',
#      u'issuer': u'rB3gZey7VWHYRqJHLoHDEJXJ2pEPNieKiS',
#      u'value': u'887.25299'},
#     u'TakerPays': u'3971232',
#     u'TransactionType': u'OfferCreate',
#     u'TxnSignature': u'304402205D5FBEDA383D3A098FAD7F6F9F1B99A9F89C99FD1C5EBBA0A420FF3248706907022030BFDD45AB55CF8A14C8A80484DA70D784EEFB11E68A6FD45536BD9871A2761F'}},
#   {u'date': u'2017-12-31T00:00:02+00:00',
#    u'hash': u'A9D428733DCCA61AD8E12EAA1C95660EA5ADEE8F58164A465DE397730AC826F2',
#    u'ledger_hash': u'4334913C17916BB4CC71B1F307477CB06751E26355048B47044B75E8915CA682',
#    u'ledger_index': 35444821,
#    u'meta': {u'AffectedNodes': [{u'CreatedNode': {u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'2B6AE3B4D23B92550AA827D1C7B6662DB4A5CC39F8DB32172FD49FB86D6EE285',
#        u'NewFields': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'BookDirectory': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F9FAEDB7D23E',
#         u'OwnerNode': u'0000000000003FF1',
#         u'Sequence': 1501598,
#         u'TakerGets': {u'currency': u'USD',
#          u'issuer': u'rB3gZey7VWHYRqJHLoHDEJXJ2pEPNieKiS',
#          u'value': u'7.4348069'},
#         u'TakerPays': u'3971232'}}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000003FF0',
#         u'Owner': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'RootIndex': u'C5383B94DDE4BE2A184757D80837080C4D1EAB80789FE39F7D7AECFB0D0304BB'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'382B968C19B4822299A603F8201A7849A8AECA4C348FBF5B6B2A6670761BD0D4'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexNext': u'0000000000003FF1',
#         u'IndexPrevious': u'0000000000003FEF',
#         u'Owner': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'RootIndex': u'C5383B94DDE4BE2A184757D80837080C4D1EAB80789FE39F7D7AECFB0D0304BB'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'66C62241283677980610CA61B6001B9BD382717A1501451ECADFC2200BD5030A'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'Balance': u'7938494202',
#         u'Flags': 0,
#         u'OwnerCount': 102,
#         u'Sequence': 1501599},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'72A59CDF8FFBF65C20D01D3A3D5DA5BAE3158A3881E7AEE525A01B1CC73D32DD',
#        u'PreviousFields': {u'Balance': u'7938494217', u'Sequence': 1501598},
#        u'PreviousTxnID': u'5133E56B26F81A0DFE465E35EEEDD88F5B0D4F35B7E10C225594AC3D6A5113B2',
#        u'PreviousTxnLgrSeq': 35444821}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#         u'BookDirectory': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F78D4CCEC865',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 0,
#         u'OwnerNode': u'0000000000003FF0',
#         u'PreviousTxnID': u'E2A0C02656FA2DC4D430C20A7BC1DC9F0B1646147A63F3B76E4F3A7AD6F5848B',
#         u'PreviousTxnLgrSeq': 35444791,
#         u'Sequence': 1501582,
#         u'TakerGets': {u'currency': u'USD',
#          u'issuer': u'rB3gZey7VWHYRqJHLoHDEJXJ2pEPNieKiS',
#          u'value': u'7.4348069'},
#         u'TakerPays': u'3969247'},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'C6A3D825AAAFE9C30007697D030608B5AEC10CC32B8383C5C09C92A5A58A82C3'}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'5A12F78D4CCEC865',
#         u'Flags': 0,
#         u'RootIndex': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F78D4CCEC865',
#         u'TakerGetsCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerGetsIssuer': u'6F2531F2B8CDB96D6D986D9D75CC0156DF2C5387',
#         u'TakerPaysCurrency': u'0000000000000000000000000000000000000000',
#         u'TakerPaysIssuer': u'0000000000000000000000000000000000000000'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F78D4CCEC865'}},
#      {u'CreatedNode': {u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F9FAEDB7D23E',
#        u'NewFields': {u'ExchangeRate': u'5A12F9FAEDB7D23E',
#         u'RootIndex': u'EACCD320D7E05EEBC6D7312125D6795DBDF4010D993738BC5A12F9FAEDB7D23E',
#         u'TakerGetsCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerGetsIssuer': u'6F2531F2B8CDB96D6D986D9D75CC0156DF2C5387'}}}],
#     u'TransactionIndex': 15,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'raNDu1gNyZ5hipBTKxm5zx7NovA1rNnNRf',
#     u'Fee': u'15',
#     u'Flags': 2147483648L,
#     u'LastLedgerSequence': 35444822,
#     u'OfferSequence': 1501582,
#     u'Sequence': 1501598,
#     u'SigningPubKey': u'02E2F1208D1715E18B0957FC819546FA7434B4A19EE38321932D2ED28FA090678E',
#     u'TakerGets': {u'currency': u'USD',
#      u'issuer': u'rB3gZey7VWHYRqJHLoHDEJXJ2pEPNieKiS',
#      u'value': u'7.4348069'},
#     u'TakerPays': u'3971232',
#     u'TransactionType': u'OfferCreate',
#     u'TxnSignature': u'3045022100FFAB71B7D35B497D72679B9D23A7F3B27FB7B8CB95F055F58EC0A6B72F78F5C80220212CED8FA6E5A28EC89ADB94D506160CDDF57C64F95451407E951CE6435FB992'}},
#   {u'date': u'2017-12-31T00:00:02+00:00',
#    u'hash': u'9E168CA57C0CC3D3E9172BF458EB4C7F5C279A74945808EBB86CA0DCAD6394C8',
#    u'ledger_hash': u'4334913C17916BB4CC71B1F307477CB06751E26355048B47044B75E8915CA682',
#    u'ledger_index': 35444821,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'2FAF05CA131C0C89B113880C030C36240B37EBA5AEB681323DD42054DC928F47',
#        u'PreviousTxnID': u'AAD79FC1C242E22ECD449CD285CE225B4BBCCCDBE4B6837AC5E549351D09368F',
#        u'PreviousTxnLgrSeq': 35444800}},
#      {u'CreatedNode': {u'LedgerEntryType': u'RippleState',
#        u'LedgerIndex': u'33C2EC138B90D29B54B325C1E916E8459C974883FD33B4E7814DD8627ACEB5B8',
#        u'NewFields': {u'Balance': {u'currency': u'BTC',
#          u'issuer': u'rrrrrrrrrrrrrrrrrrrrBZbvji',
#          u'value': u'0'},
#         u'Flags': 2228224,
#         u'HighLimit': {u'currency': u'BTC',
#          u'issuer': u'raEiBHXa5bSv63JKe5kNcBpYhgDnp2TCLd',
#          u'value': u'1000000000'},
#         u'LowLimit': {u'currency': u'BTC',
#          u'issuer': u'rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL',
#          u'value': u'0'},
#         u'LowNode': u'0000000000000B98'}}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'raEiBHXa5bSv63JKe5kNcBpYhgDnp2TCLd',
#         u'Balance': u'1302730044',
#         u'Flags': 0,
#         u'OwnerCount': 1,
#         u'Sequence': 2},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'6435E9229C47AC420ACB25AE8442D0E58D6BD40975D31CB12E7D7274EC3B6E0E',
#        u'PreviousFields': {u'Balance': u'1302730059',
#         u'OwnerCount': 0,
#         u'Sequence': 1},
#        u'PreviousTxnID': u'DB4F2BE6902BEBD70C6C52D21BFCF0F324EE507271C7A0D22088725A93DCA3D5',
#        u'PreviousTxnLgrSeq': 35428273}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000000B97',
#         u'Owner': u'rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL',
#         u'RootIndex': u'AC7D605DC4B0E09BB9BA05DF47C1D6CFC01688603B14D86BB0E3896B910EF4B4'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'ACA73BF01ACEE284B06B702528BA69C32429243C526A1ACDE0E1B1FB74A6DE03'}},
#      {u'CreatedNode': {u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'B796213030122C84EEEA76FCCC203C405AA1AB19358DE1757F4B82CF24CC1421',
#        u'NewFields': {u'Owner': u'raEiBHXa5bSv63JKe5kNcBpYhgDnp2TCLd',
#         u'RootIndex': u'B796213030122C84EEEA76FCCC203C405AA1AB19358DE1757F4B82CF24CC1421'}}}],
#     u'TransactionIndex': 16,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'raEiBHXa5bSv63JKe5kNcBpYhgDnp2TCLd',
#     u'Fee': u'15',
#     u'Flags': 2147614720L,
#     u'LastLedgerSequence': 35444825,
#     u'LimitAmount': {u'currency': u'BTC',
#      u'issuer': u'rchGBxcD1A1C2tdxF6papQYZ8kjRKMYcL',
#      u'value': u'1000000000'},
#     u'Memos': [{u'Memo': {u'MemoData': u'67617465687562',
#        u'MemoFormat': u'746578742F706C61696E',
#        u'MemoType': u'636C69656E74'}}],
#     u'Sequence': 1,
#     u'SigningPubKey': u'03141E6498B283166BEC854DDC2082E6651845F0C382B484A1EF865E2EEF0EC669',
#     u'TransactionType': u'TrustSet',
#     u'TxnSignature': u'30440220282C636126E79110D2E91DB50C4AEF6185C58E3A44C0A37C57E836AA5450884B02206D073F52FEACC0862503F7624C407B300243F596E9B6E571AAFD9E3072CEA32A'}},
#   {u'date': u'2017-12-31T00:00:02+00:00',
#    u'hash': u'84806A873961F20DB243B2F70161C4BC8A6B6F6AA072BB0C7E4F42DEFF3CE664',
#    u'ledger_hash': u'4334913C17916BB4CC71B1F307477CB06751E26355048B47044B75E8915CA682',
#    u'ledger_index': 35444821,
#    u'meta': {u'AffectedNodes': [{u'CreatedNode': {u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'421A98E4152746CE557BE836EA89FEF7853C0E7F7CE239358E13C63A075B4099',
#        u'NewFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'BookDirectory': u'4627DFFCFF8B5A265EDBD8AE8C14A52325DBFEDAF4F5C32E5A12BA6C1063C4C0',
#         u'Flags': 196608,
#         u'OwnerNode': u'0000000000000003',
#         u'Sequence': 380210,
#         u'TakerGets': {u'currency': u'USD',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'80'},
#         u'TakerPays': u'42172183'}}},
#      {u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000000000',
#         u'Owner': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'RootIndex': u'474763B38603F1175E71CB4BEA3DFDD5934D5EC0AAB7E8D62F41C01FA436F7E7'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'45C7B0E22DD46631561CCA7E7061A94D5CB89834458C637A11DBA96490FA8DB6'}},
#      {u'CreatedNode': {u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'4627DFFCFF8B5A265EDBD8AE8C14A52325DBFEDAF4F5C32E5A12BA6C1063C4C0',
#        u'NewFields': {u'ExchangeRate': u'5A12BA6C1063C4C0',
#         u'RootIndex': u'4627DFFCFF8B5A265EDBD8AE8C14A52325DBFEDAF4F5C32E5A12BA6C1063C4C0',
#         u'TakerGetsCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerGetsIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1'}}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'Balance': u'274835085',
#         u'Flags': 8388608,
#         u'OwnerCount': 7,
#         u'Sequence': 380211},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'EF6794F5513959B2837E95BF3A1F8566A2ADD72D6AE3DD74B2B0D0A34C489B4C',
#        u'PreviousFields': {u'Balance': u'274835097',
#         u'OwnerCount': 6,
#         u'Sequence': 380210},
#        u'PreviousTxnID': u'9FD35455AED3E1A0360BF520E1F168429A13B1C0C880518BE838CCAA93805B1E',
#        u'PreviousTxnLgrSeq': 35444820}}],
#     u'TransactionIndex': 17,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#     u'Fee': u'12',
#     u'Flags': 2148073472L,
#     u'LastLedgerSequence': 35444822,
#     u'Sequence': 380210,
#     u'SigningPubKey': u'0291D2EBF202C1F09DA301078ADD497797CD66CD5AA5AB667D0EB3B61FA600F54D',
#     u'TakerGets': {u'currency': u'USD',
#      u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#      u'value': u'80'},
#     u'TakerPays': u'42172183',
#     u'TransactionType': u'OfferCreate',
#     u'TxnSignature': u'3044022013B8612383D8582D05D93486F652B05B73BC7496362E1EBDF0B3729D7808CE9902204B986B980C8AF3D77A36A0DE4508485A8B37EC5E688017CDCC2227C2C38F4996'}},
#   {u'date': u'2017-12-31T00:00:02+00:00',
#    u'hash': u'A88FE46C54E0DB7309122461910AC7AD96935CE7F600DA1940F320569A57126C',
#    u'ledger_hash': u'4334913C17916BB4CC71B1F307477CB06751E26355048B47044B75E8915CA682',
#    u'ledger_index': 35444821,
#    u'meta': {u'AffectedNodes': [{u'ModifiedNode': {u'FinalFields': {u'Flags': 0,
#         u'IndexPrevious': u'0000000000000000',
#         u'Owner': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'RootIndex': u'474763B38603F1175E71CB4BEA3DFDD5934D5EC0AAB7E8D62F41C01FA436F7E7'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'45C7B0E22DD46631561CCA7E7061A94D5CB89834458C637A11DBA96490FA8DB6'}},
#      {u'DeletedNode': {u'FinalFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'BookDirectory': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06F1D8BB794328',
#         u'BookNode': u'0000000000000000',
#         u'Flags': 65536,
#         u'OwnerNode': u'0000000000000003',
#         u'PreviousTxnID': u'C9B690BC311F4B838F15A6378B2B08FBE7816BB35A3D9D70442A1E3918346A34',
#         u'PreviousTxnLgrSeq': 35444818,
#         u'Sequence': 380203,
#         u'TakerGets': u'40925677',
#         u'TakerPays': {u'currency': u'USD',
#          u'issuer': u'rvYAfWj5gh67oV6fW32ZzP3Aw4Eubs59B',
#          u'value': u'80'}},
#        u'LedgerEntryType': u'Offer',
#        u'LedgerIndex': u'8F3C1C4D96A53C3A2DA529767A5DB15DEB4522FA74B1C02D5B2A20849DD37AD3'}},
#      {u'DeletedNode': {u'FinalFields': {u'ExchangeRate': u'4F06F1D8BB794328',
#         u'Flags': 0,
#         u'RootIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06F1D8BB794328',
#         u'TakerGetsCurrency': u'0000000000000000000000000000000000000000',
#         u'TakerGetsIssuer': u'0000000000000000000000000000000000000000',
#         u'TakerPaysCurrency': u'0000000000000000000000005553440000000000',
#         u'TakerPaysIssuer': u'0A20B3C85F482532A9578DBB3950B85CA06594D1'},
#        u'LedgerEntryType': u'DirectoryNode',
#        u'LedgerIndex': u'DFA3B6DDAB58C7E8E5D944E736DA4B7046C30E4F460FD9DE4F06F1D8BB794328'}},
#      {u'ModifiedNode': {u'FinalFields': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#         u'Balance': u'274835073',
#         u'Flags': 8388608,
#         u'OwnerCount': 6,
#         u'Sequence': 380212},
#        u'LedgerEntryType': u'AccountRoot',
#        u'LedgerIndex': u'EF6794F5513959B2837E95BF3A1F8566A2ADD72D6AE3DD74B2B0D0A34C489B4C',
#        u'PreviousFields': {u'Balance': u'274835085',
#         u'OwnerCount': 7,
#         u'Sequence': 380211},
#        u'PreviousTxnID': u'84806A873961F20DB243B2F70161C4BC8A6B6F6AA072BB0C7E4F42DEFF3CE664',
#        u'PreviousTxnLgrSeq': 35444821}}],
#     u'TransactionIndex': 18,
#     u'TransactionResult': u'tesSUCCESS'},
#    u'tx': {u'Account': u'rnt9HnGsrEwqpneD4XTbCXuvZxrM2c3EqA',
#     u'Fee': u'12',
#     u'Flags': 2147483648L,
#     u'LastLedgerSequence': 35444823,
#     u'OfferSequence': 380203,
#     u'Sequence': 380211,
#     u'SigningPubKey': u'0291D2EBF202C1F09DA301078ADD497797CD66CD5AA5AB667D0EB3B61FA600F54D',
#     u'TransactionType': u'OfferCancel',
#     u'TxnSignature': u'3044022059D954AA559CF01AA2A264C554EB3F973ACE2B4BAC7C121956C31147B088A49002200EA1EB9FC0434932C36E620F867300BCA0E440DAD418DACBA81960817C3CF7CD'}}]}

# %%
# Timestamp
# Unique Hash
# Account Sending
# Account Receiving (May be smart contract)
# Tx Fee
# Size of Data (I don't see this here... I'll skip it for now)
# Network Name (duh)
# Transaction Status
# Value of Tx

def process_transaction_batch(transactions):
    '''
    Goes through a list of transactions from the Ripple transactions api.
    Returns a list of processed transactions.
    '''
    processed_txs = []

    for n, i in enumerate(transactions):
        tx_datetime = parser.parse(i['date'])
        tx_formatted_date = tx_datetime.strftime("%Y-%m-%d %H:%M:%S")
        unix_timestamp = int(time.mktime(tx_datetime.timetuple()))

        next_tx = {'datetime': tx_formatted_date, 'unixtimestamp': unix_timestamp, 'network': "Ripple"}

        #Unique Hash
        next_tx['txhash'] = i['hash']

        #Transaction Type
        transaction_type = i['tx']['TransactionType']
        next_tx['txtype'] = transaction_type

        #Fee
        next_tx['txfee'] = '{0:f}'.format(float(i['tx']['Fee'])/float(1000000))
        next_tx['txfeedenom'] = 'XRP'

        if transaction_type == "OfferCreate":      

            #Sender Pays in not XRP, and receives not XRP
            if type(i['tx']["TakerGets"]) == type({}) and type(i['tx']["TakerPays"]) == type({}): 

                #Account Sending
                next_tx['sender'] = i['tx']['Account']

                #Amount Sent
                next_tx['valuesent'] = i['tx']['TakerGets']['value']

                #Amount Sent Denomination
                next_tx['valuesentdenom'] = i['tx']['TakerGets']['currency']

                #Account Receiving
                next_tx['receiver'] = "Unknown"

                #Amount Received
                next_tx['valuereceived'] = i['tx']['TakerPays']['value']

                #Received Denomination
                next_tx['valuereceiveddenom'] = i['tx']['TakerPays']['currency']


            #Sender Pays in XRP, but Receives not XRP    
            elif type(i['tx']["TakerGets"]) != type({}) and type(i['tx']["TakerPays"]) == type({}): 
                #Account Sending
                next_tx['sender'] = i['tx']['Account']

                #Amount Sent
                next_tx['valuesent'] = '{0:f}'.format(int(i['tx']['TakerGets'])/float(1000000))

                #Amount Sent Denomination
                next_tx['valuesentdenom'] = 'XRP'

                #Account Receiving
                next_tx['receiver'] = "Unknown"

                #Amount Received
                next_tx['valuereceived'] = i['tx']['TakerPays']['value']

                #Received Denomination
                next_tx['valuereceiveddenom'] = i['tx']['TakerPays']['currency']

            #Sender Pays in not XRP and receives XRP
            elif type(i['tx']["TakerGets"]) == type({}) and type(i['tx']["TakerPays"]) != type({}): 
                #Account Sending
                next_tx['sender'] = i['tx']['Account']

                #Amount Sent
                next_tx['valuesent'] = i['tx']['TakerGets']['value']

                #Amount Sent Denomination
                next_tx['valuesentdenom'] = i['tx']['TakerGets']['currency']

                #Account Receiving
                next_tx['receiver'] = "Unknown"

                #Amount Received
                next_tx['valuereceived'] = '{0:f}'.format(int(i['tx']['TakerPays'])/float(1000000))

                #Received Denomination
                next_tx['valuereceiveddenom'] = 'XRP'

            #Sender Pays in XRP and Receives XRP
            else:

                #Account Sending
                next_tx['sender'] = i['tx']['Account']

                #Amount Sent
                next_tx['valuesent'] = '{0:f}'.format(int(i['tx']['TakerGets'])/float(1000000))

                #Amount Sent Denomination
                next_tx['valuesentdenom'] = 'XRP'

                #Account Receiving
                next_tx['receiver'] = "Unknown"

                #Amount Received
                next_tx['valuereceived'] = '{0:f}'.format(int(i['tx']['TakerPays'])/float(1000000))

                #Received Denomination
                next_tx['valuereceiveddenom'] = 'XRP'

        elif transaction_type == 'Payment':
                #Account Sender
                next_tx['sender'] = i['tx']['Account']

                #Account Receiving
                next_tx['receiver'] = i['tx']['Destination']
                
                #Sometimes payments are in amounts other than XRP
                if type(i['tx']['Amount']) == type({}):
                    #Amount Received
                    next_tx['valuereceived'] = i['tx']['Amount']['value']
                    
                    #Received Denomination
                    next_tx['valuereceiveddenom'] = i['tx']['Amount']['currency']

                    #Amount Sent
                    next_tx['valuesent'] = i['tx']['Amount']['value']
                    
                    #Amount Sent Denomination
                    next_tx['valuesentdenom'] = i['tx']['Amount']['currency']
                
                else:
                    #Amount Received
                    next_tx['valuereceived'] = '{0:f}'.format(int(i['tx']['Amount'])/float(1000000))
                    
                    #Received Denomination
                    next_tx['valuereceiveddenom'] = 'XRP'

                    #Amount Sent
                    next_tx['valuesent'] = '{0:f}'.format(int(i['tx']['Amount'])/float(1000000))
                    
                    #Amount Sent Denomination
                    next_tx['valuesentdenom'] = 'XRP'
                
        processed_txs.append(next_tx)

    return processed_txs

# %%
processed_txs = []
params = {"start": iso_starting_datetime , "end" : iso_ending_timestamp, "limit" : 100}

for i in range(total_api_calls):
    if i%10 == 0:
        print "Number of Cycles: " + str(i)
        print datetime.datetime.now()
    resp = requests.get(url_endpoint, params=params)
    resp_dict = json.loads(resp.content)
    transactions = resp_dict['transactions']
    processed_txs = processed_txs + process_transaction_batch(transactions)
    if 'marker' in resp_dict:
        params['marker'] = resp_dict['marker']
    else:
        break
# Out:
# Number of Cycles: 0
# 2018-01-05 16:59:09.899000
# Number of Cycles: 10
# 2018-01-05 16:59:37.407000
# Number of Cycles: 20
# 2018-01-05 17:00:03.741000
# Number of Cycles: 30
# 2018-01-05 17:00:30.066000
# Number of Cycles: 40
# 2018-01-05 17:00:55.321000
# Number of Cycles: 50
# 2018-01-05 17:01:17.893000
# Number of Cycles: 60
# 2018-01-05 17:01:44.059000
# Number of Cycles: 70
# 2018-01-05 17:02:11.624000
# Number of Cycles: 80
# 2018-01-05 17:02:36.562000
# Number of Cycles: 90
# 2018-01-05 17:02:59.391000

# %%
df = pandas.DataFrame.from_dict(processed_txs)

df.to_csv("Ripple_20171231_transactions.csv")

# %%
len(processed_txs)
# Out:
# 10000
