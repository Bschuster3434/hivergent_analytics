# %%
import pandas
import requests
from requests.compat import urljoin
import datetime
import time
import json

# %%
#Appears to be a freely available BTC API
#https://btc.com/api-doc#General

# %%
#Starting Point for analysis
starting_block = 501798 #Dec 31st 2017 start
ending_block = 501960 #Dec 31st 2017 end
get_blocks_by_range = 10
satoshi_to_BTC = 100000000

# %%
#https://chain.api.btc.com/v3/block/3
url_endpoint = "https://chain.api.btc.com"

# %%
#Datapoints per transaction needed
# Timestamp
# Unique Hash
# Account Sending
# Account Receiving (May be smart contract)
# Tx Fee
# Size of Data
# Network Name (duh)
# Transaction Status
# Value of Transaction

# %%
processed_txs = []

for b in range(get_blocks_by_range):
    next_block = starting_block + b
    next_url_call = urljoin(url_endpoint, "v3/block/" + str(next_block) + "/tx")
    resp = json.loads(requests.get(next_url_call).content)

    transactions = resp['data']['list']

    for i in transactions:
        next_tx = {'network': "Bitcoin"}

        #Unique Hash
        next_tx['txhash'] = i['hash']

        #Timestamps
        timestamp = i['block_time']
        next_tx['unixtimestamp'] = timestamp
        next_tx['datetime'] = datetime.datetime.fromtimestamp(timestamp).strftime("%Y-%m-%d %H:%M:%S")

        #Account Sending
        if i['is_coinbase']:
            next_tx['sender'] = 'Coinbase' #Can we do a numeric value to define coinbase?
        else:
            next_tx['sender'] = "SomeNumberOfSenders"

        #Account Receiving
        next_tx['receiver'] = "SomeNumberOfReceivers"

        #TxFee
        if i['is_coinbase']:
            next_tx['txfee'] = 0
        else:
            next_tx['txfee'] = i['fee']/float(satoshi_to_BTC)

        #Status
        if i['is_double_spend']:
            next_tx['status'] = 0
        else:
            next_tx['status'] = 1

        #Value of Transaction
        next_tx['value'] = i['outputs_value']/float(satoshi_to_BTC)

        processed_txs.append(next_tx)
    
    time.sleep(.5)
    
    if b%10 == 0:
        print "Current Block: " + str(next_block)
        print "Total blocks processed: " + str(b)
        print "Total Transactions processed: " + str(len(processed_txs))
        print datetime.datetime.now()

print "Completed"
print datetime.datetime.now()
# Out:
# Current Block: 501798
# Total blocks processed: 0
# Total Transactions processed: 50
# 2018-01-09 11:24:39.378000
# Completed
# 2018-01-09 11:24:47.837000

# %%
transactions[4]
# Out:
# {u'block_height': 501807,
#  u'block_time': 1514682087,
#  u'confirmations': 1560,
#  u'created_at': 1514681957,
#  u'fee': 1995708,
#  u'hash': u'c24606e94c15bf352d805bb5606d7ce94cd7e4e8f7eedfd204784ca4d7d71a5c',
#  u'inputs': [{u'prev_addresses': [u'17A16QmavnUfCW11DAApiJxp7ARnxN5pGX'],
#    u'prev_position': 30,
#    u'prev_tx_hash': u'91de8c93abd76a856b2d8b2617042469e0ebf64b21f17546b57712a96772a105',
#    u'prev_type': u'P2PKH',
#    u'prev_value': 430978015,
#    u'sequence': 4294967295L}],
#  u'inputs_count': 1,
#  u'inputs_value': 430978015,
#  u'is_coinbase': False,
#  u'is_double_spend': False,
#  u'is_sw_tx': False,
#  u'lock_time': 0,
#  u'outputs': [{u'addresses': [u'1NsgSazAJjvZdzPNASjj6FCuzaRLUCh5HP'],
#    u'spent_by_tx': u'641a68010f21ea5c1e53c3f6c75c6a109f0a5589ad91ca81d617759a94517919',
#    u'spent_by_tx_position': 188,
#    u'type': u'P2PKH',
#    u'value': 168181},
#   {u'addresses': [u'14j7eXNUhkcCD8sL1Y36WRzwDamn3m8JxV'],
#    u'spent_by_tx': u'2ef613f4f28aedb713e7eefb20c7df2d8a95fd1d8bd3ebf0ffbb03bd27696288',
#    u'spent_by_tx_position': 1,
#    u'type': u'P2PKH',
#    u'value': 244444},
#   {u'addresses': [u'3LwBSdP6toQxxT4hZW7gDo1V74KPiiqvZ1'],
#    u'spent_by_tx': u'5b56827ade44e777ff1b6234055eee53c080826acc193a52021fc73c5abfa6f4',
#    u'spent_by_tx_position': 37,
#    u'type': u'P2SH',
#    u'value': 384406},
#   {u'addresses': [u'1GFxD2upKFD4Uy7hBvQeMVpEaphDzGRfEr'],
#    u'spent_by_tx': u'd29be43574bcad3c21f7ef13e1e38ce67e9a32ce5be3bf712ac9ad17e98b8577',
#    u'spent_by_tx_position': 8,
#    u'type': u'P2PKH',
#    u'value': 631200},
#   {u'addresses': [u'1K3fexL8kjPPXNwSv979pKTJEeYMdfKpLA'],
#    u'spent_by_tx': u'119862dfb0dda43093a26bb48b836b78b2c9a34751d1ae05c692d0fd5e9ae898',
#    u'spent_by_tx_position': 1,
#    u'type': u'P2PKH',
#    u'value': 844058},
#   {u'addresses': [u'3Hsj6w96AwSGVv8Q85qcBXJG7N6ySGJted'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2SH',
#    u'value': 1019941},
#   {u'addresses': [u'331FN1C9NBRAWMr36Ni5FZPLqyiLkD88Rr'],
#    u'spent_by_tx': u'95029462b71eac998b579a0c62740ec937af6af4bc8982a27dfc10f066562c84',
#    u'spent_by_tx_position': 1,
#    u'type': u'P2SH',
#    u'value': 1300000},
#   {u'addresses': [u'18eEBneNsbSV1Liwrq8gMK8pmufBqCD7PD'],
#    u'spent_by_tx': u'67f76091b73b65a51e257f7d11f6599b9a4745a02493bb925d39e83f21b36476',
#    u'spent_by_tx_position': 14,
#    u'type': u'P2PKH',
#    u'value': 3323971},
#   {u'addresses': [u'1K4TVQ2iyn7vsFSSKQLPg45CyPTnowR1pU'],
#    u'spent_by_tx': u'd30c28a42c328e6de4164137f06e6148ba52d357018f3a2c3f2bc916bd5753ca',
#    u'spent_by_tx_position': 125,
#    u'type': u'P2PKH',
#    u'value': 3634703},
#   {u'addresses': [u'1P7eHKbYHg3jbJvpqw7n5wRwEDaHMi2ate'],
#    u'spent_by_tx': u'80da0e2b4e777949ac95ada10de417098a5d8b62e0944ba69040509ad339cf96',
#    u'spent_by_tx_position': 245,
#    u'type': u'P2PKH',
#    u'value': 5000000},
#   {u'addresses': [u'1LLYiJgc95uvwbp9ywtyFUk9p549yHz57D'],
#    u'spent_by_tx': u'd29be43574bcad3c21f7ef13e1e38ce67e9a32ce5be3bf712ac9ad17e98b8577',
#    u'spent_by_tx_position': 28,
#    u'type': u'P2PKH',
#    u'value': 5719016},
#   {u'addresses': [u'1P6WCy21awZG28yzEotozbjizUinB4J7J7'],
#    u'spent_by_tx': u'83b83860ab2a2345805525ab47fcd3f91eace9056651543d0222a0ae1d34738c',
#    u'spent_by_tx_position': 230,
#    u'type': u'P2PKH',
#    u'value': 7838133},
#   {u'addresses': [u'1LLeR2KZwiixSegq25VF2q2aRTSKKKQKM1'],
#    u'spent_by_tx': u'd5301764f1e01f16e55b8d5cba9d17e141d732e0e8690e443764af43ca2a7818',
#    u'spent_by_tx_position': 28,
#    u'type': u'P2PKH',
#    u'value': 9950000},
#   {u'addresses': [u'1USDc4jjgGXv8H6HtsyqGZVhHAuttKzRC'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2PKH',
#    u'value': 9985976},
#   {u'addresses': [u'3GBHDectQPj3qFrNqznVGLZyHogJ9fjKfv'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2SH',
#    u'value': 10750478},
#   {u'addresses': [u'368PGPNKAnmh9PaJaYsDCMBoTR4VgQKZU9'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2SH',
#    u'value': 11350000},
#   {u'addresses': [u'1EpoJVxiRodd2bUVaJVKdBsy5AqfwYvE6U'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2PKH',
#    u'value': 11950000},
#   {u'addresses': [u'3PmGL1un5YPnFqPB3reHbZH5j7YisZmxXt'],
#    u'spent_by_tx': None,
#    u'spent_by_tx_position': -1,
#    u'type': u'P2SH',
#    u'value': 14950000},
#   {u'addresses': [u'1QDeErKNkpsQvvVXXwGf3obfQhge34zrrJ'],
#    u'spent_by_tx': u'a8ff128edaca520f80584870f6f4e8401666e06693dc785cf6e4c7a6f4d1cec3',
#    u'spent_by_tx_position': 1,
#    u'type': u'P2PKH',
#    u'value': 15250000},
#   {u'addresses': [u'1G2pjpu6FBH2wkcfAY2kcnZrDkNuq124Xt'],
#    u'spent_by_tx': u'c3713b491c55fe78274df25cc03d34afbf384c9113b501f7dd535ece935bbf7e',
#    u'spent_by_tx_position': 135,
#    u'type': u'P2PKH',
#    u'value': 20000000},
#   {u'addresses': [u'32tvuhAXHuyees7RbaD8Xgt8WpxBhYoKcc'],
#    u'spent_by_tx': u'16409af997f82f2fa6279e9d53604429c3657b5b1b0bb929d8c51d2878cb671e',
#    u'spent_by_tx_position': 16,
#    u'type': u'P2SH',
#    u'value': 30000000},
#   {u'addresses': [u'18osGnYucU7F4srqS9qeLwCa78gEoiELXm'],
#    u'spent_by_tx': u'67f76091b73b65a51e257f7d11f6599b9a4745a02493bb925d39e83f21b36476',
#    u'spent_by_tx_position': 15,
#    u'type': u'P2PKH',
#    u'value': 35776997},
#   {u'addresses': [u'1HK5GqQvT5Qh6QqYyZRF7KERtYj4Ve2gnK'],
#    u'spent_by_tx': u'd1966f9775c305feaba4a4b8b0cc183f80aea0d9a42525e1b79d771e3ca2f8e5',
#    u'spent_by_tx_position': 0,
#    u'type': u'P2PKH',
#    u'value': 59927186},
#   {u'addresses': [u'138Lu7ouM1jmjCyLrzrHz9gw79HxLT8rhT'],
#    u'spent_by_tx': u'1e0e2b771ce1565c63e7596a050f086c3b9fca99eaed0e9c80a999f102d64d0d',
#    u'spent_by_tx_position': 63,
#    u'type': u'P2PKH',
#    u'value': 59950000},
#   {u'addresses': [u'17A16QmavnUfCW11DAApiJxp7ARnxN5pGX'],
#    u'spent_by_tx': u'fce8fe99301fcb791fdfdecd0c3ea6bf0dcf44861373675f743323d1b0730a08',
#    u'spent_by_tx_position': 0,
#    u'type': u'P2PKH',
#    u'value': 109033617}],
#  u'outputs_count': 25,
#  u'outputs_value': 428982307,
#  u'sigops': 72,
#  u'size': 1026,
#  u'version': 2,
#  u'vsize': 1026,
#  u'weight': 4104,
#  u'witness_hash': u'c24606e94c15bf352d805bb5606d7ce94cd7e4e8f7eedfd204784ca4d7d71a5c'}

# %%
df = pandas.DataFrame.from_dict(processed_txs)

df.to_csv("Bitcoin_20171231_transactions.csv")
