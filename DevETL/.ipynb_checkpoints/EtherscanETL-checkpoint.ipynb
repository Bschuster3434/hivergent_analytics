# %%
import pandas
import requests
import datetime
import time
import json

# %%
etherscan_api_key = "SU775DFF8GEGMER3B8ZPK3QZIJWGIBE45T"
url_endpoint = "https://api.etherscan.io/api"

# %%
#Starting Point for analysis
starting_block = 4826779 #Dec 31st 2017 start
ending_block = 4832685 #Dec 31st 2017 end
hex_starting_block = hex(starting_block)
hex_end_block = hex(ending_block)
get_blocks_by_range = 100

# %%
wei_in_ETH = 1000000000000000000

def tx_cost_in_ETH(gasused, gasprice):
    '''
    Does the conversion to get the actual transaction fee (in ETH) for each ethereum transaction.
    '''
    cost_in_eth = (gasused * gasprice)/float(wei_in_ETH)
    return cost_in_eth

# %%
#Datapoints per transaction needed
# Timestamp
# Unique Hash
# Account Sending
# Account Receiving (May be smart contract)
# Tx Fee
# Size of Data (I don't see this here... I'll skip it for now)
# Network Name (duh)
# Transaction Status
# Value of Tx

# %%
#Transactions processed for this group of blocks
processed_txs = []

#Loop for all transactions
for i in range(get_blocks_by_range):
    #Get Transactions in a Block
    #https://github.com/ethereum/wiki/wiki/JSON-RPC#eth_gettransactionbyhash
    next_block = starting_block + i
    hex_next_block = hex(next_block)
    
    if i%10 == 0:
        print "Now on Block: " + str(next_block)
        print "Total Block Count: " + str(i)
    
    #Go and grab all transactions in the block
    params = {"module":"proxy", "action":"eth_getBlockByNumber", "tag" : hex_starting_block, "boolean":"true", "apikey": etherscan_api_key}
    resp = requests.get(url_endpoint, params=params)
    resp_dict = json.loads(resp.content) #Get a string, must eval to a dict

    #Timestamp

    timestamp = int(resp_dict['result']['timestamp'],0)
    unix_timestamp = int(resp_dict['result']['timestamp'],0)
    timestamp = datetime.datetime.fromtimestamp(timestamp).strftime("%Y-%m-%d %H:%M:%S")

    #Every other feature will be found in the transactions

    transactions = resp_dict['result']['transactions']
    transactions

    for i in transactions:
        #Initialize the next transaction
        next_tx = {'datetime': timestamp, 'unixtimestamp': unix_timestamp, 'network': "Ethereum"}

        #Unique Hash
        next_tx['txhash'] = i['hash']

        #Account Sending
        next_tx['sender'] = i['from']

        #Account Receiving
        next_tx['receiver'] = i['to']

        #Tx Fee
        #Can't evaluate the fee until we get the receipt info, which is a separate call.
        #Oh Bother.
        next_tx['gasprice'] = int(i['gasPrice'],0)  
        
        #Value
        #converting from hex, to int, then from wei to ETH
        next_tx['value'] = int(i['value'],0)/float(wei_in_ETH)

        processed_txs.append(next_tx)

#Now I'm going through and grabbing the transaction hashes

total_transactions_to_process = len(processed_txs)

print "Total count of txs: " + str(total_transactions_to_process)
print datetime.datetime.now()

for n, i in enumerate(processed_txs):
    tx_hash = i['txhash']
    
    if n%100 == 0:
        print "Total Transactions processed: " + str(n)
        print datetime.datetime.now()

    params = {"module":"proxy", "action":"eth_getTransactionReceipt", "txhash" : tx_hash, "apikey": etherscan_api_key}
    resp = requests.get(url_endpoint, params=params)
    resp_dict = json.loads(resp.content)

    i["gasused"] = int(resp_dict['result']['gasUsed'],0)
    i['status'] = int(resp_dict['result']['status'],0)
    i['txfee'] = tx_cost_in_ETH(i['gasused'], i['gasprice'])

print "Completed"
print datetime.datetime.now()

df = pandas.DataFrame.from_dict(processed_txs)

df.to_csv("20171231_transactions.csv")
# Out:
# Now on Block: 4826779
# Total Block Count: 0
# Now on Block: 4826789
# Total Block Count: 10
# Now on Block: 4826799
# Total Block Count: 20
# Now on Block: 4826809
# Total Block Count: 30
# Now on Block: 4826819
# Total Block Count: 40
# Now on Block: 4826829
# Total Block Count: 50
# Now on Block: 4826839
# Total Block Count: 60
# Now on Block: 4826849
# Total Block Count: 70
# Now on Block: 4826859
# Total Block Count: 80
# Now on Block: 4826869
# Total Block Count: 90
# Total count of txs: 5400
# 2018-01-02 12:00:21.726000
# Total Transactions processed: 0
# 2018-01-02 12:00:21.726000
# Total Transactions processed: 100
# 2018-01-02 12:01:03.780000
# Total Transactions processed: 200
# 2018-01-02 12:01:41.633000
# Total Transactions processed: 300
# 2018-01-02 12:02:20.361000
# Total Transactions processed: 400
# 2018-01-02 12:02:58.347000
# Total Transactions processed: 500
# 2018-01-02 12:03:40.965000
# Total Transactions processed: 600
# 2018-01-02 12:04:18.923000
# Total Transactions processed: 700
# 2018-01-02 12:05:02.686000
# Total Transactions processed: 800
# 2018-01-02 12:05:41.703000
# Total Transactions processed: 900
# 2018-01-02 12:06:23.183000
# Total Transactions processed: 1000
# 2018-01-02 12:07:02.276000
# Total Transactions processed: 1100
# 2018-01-02 12:07:40.389000
# Total Transactions processed: 1200
# 2018-01-02 12:08:21.877000
# Total Transactions processed: 1300
# 2018-01-02 12:09:01.496000
# Total Transactions processed: 1400
# 2018-01-02 12:09:40.028000
# Total Transactions processed: 1500
# 2018-01-02 12:10:18.657000
# Total Transactions processed: 1600
# 2018-01-02 12:10:57.079000
# Total Transactions processed: 1700
# 2018-01-02 12:11:36.422000
# Total Transactions processed: 1800
# 2018-01-02 12:12:16.997000
# Total Transactions processed: 1900
# 2018-01-02 12:12:56.885000
# Total Transactions processed: 2000
# 2018-01-02 12:13:35.914000
# Total Transactions processed: 2100
# 2018-01-02 12:14:15.212000
# Total Transactions processed: 2200
# 2018-01-02 12:14:55.439000
# Total Transactions processed: 2300
# 2018-01-02 12:15:33.641000
# Total Transactions processed: 2400
# 2018-01-02 12:16:14.053000
# Total Transactions processed: 2500
# 2018-01-02 12:16:53.080000
# Total Transactions processed: 2600
# 2018-01-02 12:17:34.243000
# Total Transactions processed: 2700
# 2018-01-02 12:18:15.386000
# Total Transactions processed: 2800
# 2018-01-02 12:18:53.251000
# Total Transactions processed: 2900
# 2018-01-02 12:19:31.740000
# Total Transactions processed: 3000
# 2018-01-02 12:20:11.128000
# Total Transactions processed: 3100
# 2018-01-02 12:20:49.208000
# Total Transactions processed: 3200
# 2018-01-02 12:21:28.572000
# Total Transactions processed: 3300
# 2018-01-02 12:22:07.165000
# Total Transactions processed: 3400
# 2018-01-02 12:22:50.899000
# Total Transactions processed: 3500
# 2018-01-02 12:23:29.536000
# Total Transactions processed: 3600
# 2018-01-02 12:24:08.658000
# Total Transactions processed: 3700
# 2018-01-02 12:24:46.861000
# Total Transactions processed: 3800
# 2018-01-02 12:25:24.621000
# Total Transactions processed: 3900
# 2018-01-02 12:26:07.492000
# Total Transactions processed: 4000
# 2018-01-02 12:26:44.868000
# Total Transactions processed: 4100
# 2018-01-02 12:27:23.835000
# Total Transactions processed: 4200
# 2018-01-02 12:28:08.707000
# Total Transactions processed: 4300
# 2018-01-02 12:28:47.420000
# Total Transactions processed: 4400
# 2018-01-02 12:29:28.994000
# Total Transactions processed: 4500
# 2018-01-02 12:30:07.232000
# Total Transactions processed: 4600
# 2018-01-02 12:30:48.933000
# Total Transactions processed: 4700
# 2018-01-02 12:31:30.106000
# Total Transactions processed: 4800
# 2018-01-02 12:32:09.365000
# Total Transactions processed: 4900
# 2018-01-02 12:32:48.552000
# Total Transactions processed: 5000
# 2018-01-02 12:33:28.718000
# Total Transactions processed: 5100
# 2018-01-02 12:34:13.003000
# Total Transactions processed: 5200
# 2018-01-02 12:34:51.547000
# Total Transactions processed: 5300
# 2018-01-02 12:35:30.470000
# Completed
# 2018-01-02 12:36:13.550000
